# %%
ls #to list files and folder in the directory
# Out:
# Python 01.ipynb      Python data.ipynb    data/
# Python 02.ipynb      TRX_cloning_program/ lessons/
# Python 04.ipynb      WinTech/

# %%
pwd  #to check which dir you are in
# Out:
# '/Users/Linda/Desktop/Python'

# %%
cd data #to enter dir "data"
# Out:
# [Errno 2] No such file or directory: 'data #to enter dir data'
# /Users/Linda/Desktop/Python

# %%
ls #to list files in the dir "data"
# Out:
# Python 01.ipynb      Python data.ipynb    data/
# Python 02.ipynb      TRX_cloning_program/ lessons/
# Python 04.ipynb      WinTech/

# %%
import pandas as pd
mtcars = pd.read_csv("~/Desktop/R program/ECOSCOPE/mtcars.csv")

# %%
mtcars #to view data "mtcars"
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars.head(5)
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
path = "~/Desktop/Python/data/mtcars.csv"
mtcars.to_csv(path) #export data to csv file in the Python folder

# %%
ls #to check if the file is exported successfully to the folder
# Out:
# Python 01.ipynb      Python data.ipynb    data/
# Python 02.ipynb      TRX_cloning_program/ lessons/
# Python 04.ipynb      WinTech/

# %%
autos = pd.read_csv("~/Desktop/Python/data/autos.csv")

# %%
autos
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# 5             5          2                 ?         audi       gas
# 6             6          1               158         audi       gas
# 7             7          1                 ?         audi       gas
# 8             8          1               158         audi       gas
# 9             9          0                 ?         audi       gas
# 10           10          2               192          bmw       gas
# 11           11          0               192          bmw       gas
# 12           12          0               188          bmw       gas
# ...

# %%
auto_path = "~/Desktop/Python/data/autos.csv"
autos = pd.read_csv(auto_path)
autos.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration n-of-doors  \
# 0          3                 ?  alfa-romero       gas        std        two
# 1          3                 ?  alfa-romero       gas        std        two
# 2          1                 ?  alfa-romero       gas        std        two
# 3          2               164         audi       gas        std       four
# 4          2               164         audi       gas        std       four
#
#     body-style   dr engine-location  wheel-base  ...    engine-size  fuel-sys  \
# 0  convertible  rwd           front        88.6  ...            130      mpfi
# 1  convertible  rwd           front        88.6  ...            130      mpfi
# 2    hatchback  rwd           front        94.5  ...            152      mpfi
# 3        sedan  fwd           front        99.8  ...            109      mpfi
# 4        sedan  4wd           front        99.4  ...            136      mpfi
#
# ...

# %%
autos = pd.read_csv(auto_path, header = None)
autos.head(5)
# Out:
#     0          1                  2            3          4           5   \
# 0  NaN  symboling  normalized-losses         make  fuel-type  aspiration
# 1  0.0          3                  ?  alfa-romero        gas         std
# 2  1.0          3                  ?  alfa-romero        gas         std
# 3  2.0          1                  ?  alfa-romero        gas         std
# 4  3.0          2                164         audi        gas         std
#
#            6            7    8                9   ...             17  \
# 0  n-of-doors   body-style   dr  engine-location  ...    engine-size
# 1         two  convertible  rwd            front  ...            130
# 2         two  convertible  rwd            front  ...            130
# 3         two    hatchback  rwd            front  ...            152
# 4        four        sedan  fwd            front  ...            109
#
#          18    19      20          21   22        23        24       25     26
# ...

# %%
headers = ["symboling", "normalized-losses", "make", "fuel-type", "aspiration", "n-of-doors", 
           "body-style", "dr", "engine-location", "wheel-base", "length", "width", "height", 
           "curb-wt", "engine-type", "n-of-cyl", "engine-size", "fuel-sys", "bore", "stroke", 
           "comp-ratio", "hp", "peak-rpm", "city-mpg", "hwy-mpg", "price"]
autos.columns = headers

# %%
path = "~/Desktop/Python/data/autos.csv"
autos.to_csv(path)

# %%
autos.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration n-of-doors  \
# 0          3                 ?  alfa-romero       gas        std        two
# 1          3                 ?  alfa-romero       gas        std        two
# 2          1                 ?  alfa-romero       gas        std        two
# 3          2               164         audi       gas        std       four
# 4          2               164         audi       gas        std       four
#
#     body-style   dr engine-location  wheel-base  ...    engine-size  fuel-sys  \
# 0  convertible  rwd           front        88.6  ...            130      mpfi
# 1  convertible  rwd           front        88.6  ...            130      mpfi
# 2    hatchback  rwd           front        94.5  ...            152      mpfi
# 3        sedan  fwd           front        99.8  ...            109      mpfi
# 4        sedan  4wd           front        99.4  ...            136      mpfi
#
# ...

# %%
autos.dtypes #to check data types
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# n-of-doors            object
# body-style            object
# dr                    object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-wt                int64
# engine-type           object
# n-of-cyl              object
# engine-size            int64
# fuel-sys              object
# bore                  object
# stroke                object
# comp-ratio           float64
# hp                    object
# peak-rpm              object
# city-mpg               int64
# hwy-mpg                int64
# price                 object
# dtype: object

# %%
autos.describe() #to return statistical summary
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#            curb-wt  engine-size  comp-ratio    city-mpg     hwy-mpg
# count   205.000000   205.000000  205.000000  205.000000  205.000000
# mean   2555.565854   126.907317   10.142537   25.219512   30.751220
# std     520.680204    41.642693    3.972040    6.542142    6.886443
# min    1488.000000    61.000000    7.000000   13.000000   16.000000
# ...

# %%
autos.describe(include = "all") #provide full statistic summary
# Out:
#          symboling normalized-losses    make fuel-type aspiration n-of-doors  \
# count   205.000000               205     205       205        205        205
# unique         NaN                52      22         2          2          3
# top            NaN                 ?  toyota       gas        std       four
# freq           NaN                41      32       185        168        114
# mean      0.834146               NaN     NaN       NaN        NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN        NaN
#
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# n-of-doors           205 non-null object
# body-style           205 non-null object
# dr                   205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-wt              205 non-null int64
# engine-type          205 non-null object
# n-of-cyl             205 non-null object
# engine-size          205 non-null int64
# fuel-sys             205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...
